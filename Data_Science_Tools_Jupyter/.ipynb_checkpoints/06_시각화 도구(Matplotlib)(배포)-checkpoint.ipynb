# %%
# 라이브러리 불러오기
import pandas as pd

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('./06시도별 전출입 인구수.xlsx', engine='openpyxl', header=0)
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %% [markdown]
# ### 셀 병합 부분이 NaN으로 표현됨
# ![image.png](attachment:image.png)

# %%
# 누락값(NaN)을 앞 데이터로 채움 (엑셀 양식 병합 부분)
df = df.fillna(method='ffill')                       # fillna : 앞에 있는 데이터 값으로 빈 공간(NaN)을 채우겠다.
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2    전국  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3    전국  부산광역시    448577    389797    362202    482061    680984    805979
# 4    전국  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
df['전출지별']
# Out:
# 0         전출지별
# 1           전국
# 2           전국
# 3           전국
# 4           전국
#         ...
# 320    제주특별자치도
# 321    제주특별자치도
# 322    제주특별자치도
# 323    제주특별자치도
# 324    제주특별자치도
# Name: 전출지별, Length: 325, dtype: object

# %%
df['전출지별'] == '서울특별시'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# Name: 전출지별, Length: 325, dtype: bool

# %%
df['전입지별']
# Out:
# 0         전입지별
# 1           전국
# 2        서울특별시
# 3        부산광역시
# 4        대구광역시
#         ...
# 320       전라북도
# 321       전라남도
# 322       경상북도
# 323       경상남도
# 324    제주특별자치도
# Name: 전입지별, Length: 325, dtype: object

# %%
df['전입지별'] != '서울특별시'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 320     True
# 321     True
# 322     True
# 323     True
# 324     True
# Name: 전입지별, Length: 325, dtype: bool

# %%
# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# Length: 325, dtype: bool

# %%
df_seoul = df[mask]
df_seoul.head(10)
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
#
#        1976     1977  ...     2008     2009     2010     2011     2012  \
# 19  2495620  2678007  ...  2083352  1925452  1848038  1834806  1658928
# ...

# %%
# 행을 축으로 하여 '전출지별' 열 삭제
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.head(10)
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
#
#        1977     1978  ...     2008     2009     2010     2011     2012  \
# ...

# %%
# 전입지별 컬럼 이름을 전입지로 변경
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.head(10)
# Out:
#         전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
#
#        1977     1978  ...     2008     2009     2010     2011     2012  \
# ...

# %%
# # 전입지 열을 인덱스로 적용
df_seoul.set_index('전입지', inplace=True)

# %%
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %%
# 경기도 행을 시리즈로 가져오기
sr_one = df_seoul.loc['경기도']
sr_one.head()
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# Name: 경기도, dtype: object

# %%
# 시각화 그래프 그리기
import matplotlib.pyplot as plt

plt.plot(sr_one.index, sr_one.values)

# %%
plt.plot(sr_one)

# %%
from matplotlib import font_manager, rc

font_path = "./06malgun.ttf"   #폰트파일의 위치

# 폰트 불러오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

# rcParam으로 폰트 설정(한글 적용을 위해)
rc('font', family=font_name)

# 그래프의 x, y범주 지정
plt.plot(sr_one.index, sr_one.values)

# 그래프의 제목
plt.title('서울 -> 경기 인구 이동')

# X축 이름
plt.xlabel('기간')

# y축 이름
plt.ylabel('이동 인구수')

# 그래프 렌더링
plt.show()

# %% [markdown]
# ##### 설명
# - 서울에서 경기로 이동한 인구에 대한 그래프 시각화
# - 년도별 증가 감소가 들쑥날쑥하지만 점점 증가하는 방향으로 갔음
# - 1995년을 정점으로 다시 감소하는 경향이 있음(올 사람 다 왔나?)
# - 그래프가 작아서 기간에 표시된 레이블이 잘 안보임

# %%
# 그래프에 속성을 추가하여 시인성을 높인다.
from matplotlib import font_manager, rc

font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 경기도 행으로 그래프 그리기
sr_one = df_seoul.loc['경기도']

# 그래프 설정(figsize=(width, height))
plt.figure(figsize=(14, 6))

plt.plot(sr_one.index, sr_one.values)
plt.title('서울 -> 경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

# x축의 눈금 레이블 회전
plt.xticks(rotation='vertical')              # x축 글자 세로로 회전

plt.show()

# %% [markdown]
# ##### 설명
# - 앞서 그렸던 그래프보다 시인성이 좋아짐

# %%
# 추가로 시각화 관련 속성 적용해보기 1
from matplotlib import font_manager, rc

font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('ggplot') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')

# x, y축 데이터를 plot 함수에 입력 - 마커 표시 추가
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)  

plt.title('서울 -> 경기 인구 이동', size=30)
plt.xlabel('기간', size=20)
plt.ylabel('이동 인구수', size=20)

# 범례 표시하기
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)

plt.show()  # 변경사항 저장하고 그래프 출력

# %%
# 추가로 시각화 관련 속성 적용해보기 2
from matplotlib import font_manager, rc

font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('classic') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)
plt.title('서울 -> 경기 인구 이동', size=30)
plt.xlabel('기간', size=20)
plt.ylabel('이동 인구수', size=20)

plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)

plt.show()
# Out:
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 추가로 시각화 관련 속성 적용해보기 3
from matplotlib import font_manager, rc
font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('bmh') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)
plt.title('서울 -> 경기 인구 이동', size=30)
plt.xlabel('기간', size=20)
plt.ylabel('이동 인구수', size=20)
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)
plt.show()

# %%
# 추가로 시각화 관련 속성 적용해보기 4
from matplotlib import font_manager, rc
font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('dark_background') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)  # 마커 표시 추가
plt.title('서울 -> 경기 인구 이동', size=30)  #차트 제목
plt.xlabel('기간', size=20)                  #x축 이름
plt.ylabel('이동 인구수', size=20)           #y축 이름
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)   #범례 표시
plt.show()  # 변경사항 저장하고 그래프 출력

# %%
# 추가로 시각화 관련 속성 적용해보기 4
from matplotlib import font_manager, rc

font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('fast') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)  # 마커 표시 추가
plt.title('서울 -> 경기 인구 이동', size=30)  #차트 제목
plt.xlabel('기간', size=20)                  #x축 이름
plt.ylabel('이동 인구수', size=20)           #y축 이름
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)   #범례 표시
plt.show()  # 변경사항 저장하고 그래프 출력

# %%
# 추가로 시각화 관련 속성 적용해보기 5
from matplotlib import font_manager, rc
font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('grayscale') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)  # 마커 표시 추가
plt.title('서울 -> 경기 인구 이동', size=30)  #차트 제목
plt.xlabel('기간', size=20)                  #x축 이름
plt.ylabel('이동 인구수', size=20)           #y축 이름
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)   #범례 표시
plt.show()  # 변경사항 저장하고 그래프 출력

# %%
# 추가로 시각화 관련 속성 적용해보기 6
from matplotlib import font_manager, rc
font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('seaborn') 

plt.figure(figsize=(14, 5))
plt.xticks(size=10, rotation='vertical')
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)  # 마커 표시 추가
plt.title('서울 -> 경기 인구 이동', size=30)  #차트 제목
plt.xlabel('기간', size=20)                  #x축 이름
plt.ylabel('이동 인구수', size=20)           #y축 이름
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)   #범례 표시
plt.show()  # 변경사항 저장하고 그래프 출력
# Out:
# C:\Users\denni\AppData\Local\Temp\ipykernel_12548\1343915450.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 사용 가능한 스타일 확인
import matplotlib.pyplot as plt

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### 이 후 내용을 참고 하여 시각화 시 스타일 적용
# - 도움말
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc

font_path = "./06malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('06시도별 전출입 인구수.xlsx', engine= 'openpyxl', header=0)

# 전출지별에서 누락값(NaN)을 앞 데이터로 채움 (엑셀 양식 병합 부분)
df = df.fillna(method='ffill')

# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 서울에서 경기도로 이동한 인구 데이터 값만 선택
sr_one = df_seoul.loc['경기도']

# 스타일 서식 지정
plt.style.use('ggplot') 

# 그림 사이즈 늘리기
plt.figure(figsize=(14, 5))

# x축 눈금 라벨 회전하기
plt.xticks(size=10, rotation='vertical')

# x, y축 데이터를 plot 함수에 입력 
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10)  # 마커 표시 추가

plt.title('서울 -> 경기 인구 이동', size=30)  #차트 제목
plt.xlabel('기간', size=20)                  #x축 이름
plt.ylabel('이동 인구수', size=20)           #y축 이름

#범례 표시
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)

# y축 범위 지정 (최소값, 최대값)
plt.ylim(50000, 800000)

# 주석 표시 - 화살표
plt.annotate('',
             xy=(20, 620000),       #화살표의 머리 부분(끝점)
             xytext=(2, 290000),    #화살표의 꼬리 부분(시작점)
             xycoords='data',       #좌표체계
             arrowprops=dict(arrowstyle='->', color='skyblue', lw=5), #화살표 서식
             )

plt.annotate('',
             xy=(47, 450000),       #화살표의 머리 부분(끝점)
             xytext=(30, 580000),   #화살표의 꼬리 부분(시작점)
             xycoords='data',       #좌표체계
             arrowprops=dict(arrowstyle='->', color='olive', lw=5),  #화살표 서식
             )

# 주석 표시 - 텍스트
plt.annotate('인구이동 증가(1970-1995)',  #텍스트 입력
             xy=(10, 550000),            #텍스트 위치 기준점
             rotation=25,                #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=15,                #텍스트 크기
             )

plt.annotate('인구이동 감소(1995-2017)',  #텍스트 입력
             xy=(40, 560000),            #텍스트 위치 기준점
             rotation=-11,               #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=15,                #텍스트 크기
             )

plt.show()  # 변경사항 저장하고 그래프 출력

# %% [markdown]
# ##### 설명
# - 우리나라 인구의 절반이 거주하는 서울특별시와 경기도 간의 인구이동 변화를 화살표로 파악할 수 있음
# - 1990년대 경기도권 5대 신도시(분당, 일산 등) 개발로 서울 인구의 대규모 경기도 유입이 있었음을 추정
# - 이 시기를 정점으로 서울을 벗어나 경기권으로 이동하는 인구는 점점 감소하는 추세

# %% [markdown]
# ### 화면 분할(그래프 여러 개 그리기)
# - 화면을 여러 개로 분할하여 각 화면에 다른 그래프를 그리는 방법
# - 여러 개의 axe객체를 생성하여 분할된 화면 마가 axe객체를 하나씩 배정
# - 하나의 화면에서 여러 그래프 비교
# 	- figure()함수로 그래프를 그릴 틀을 지정
# 	- figsize 옵션으로 그림 틀의 크기 설정
# 	- fig객체에 add_subplot()메서드를 적용하여 여러 개로 분할(각각이 axe객체)
#     ![image-2.png](attachment:image-2.png)

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

df = pd.read_excel('시도별 전출입 인구수.xlsx', engine= 'openpyxl', header=0)
df = df.fillna(method='ffill')

mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

sr_one = df_seoul.loc['경기도']
plt.style.use('ggplot') 

# 그래프 객체 생성 (figure에 2개의 서브 플롯을 생성)
fig = plt.figure(figsize=(10, 10))   
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

# axe 객체에 plot 함수로 그래프 출력
ax1.plot(sr_one, 'o', markersize=10)
ax2.plot(sr_one, marker='o', markerfacecolor='green', markersize=10, 
         color='olive', linewidth=2, label='서울 -> 경기')
ax2.legend(loc='best')

#y축 범위 지정 (최소값, 최대값)
ax1.set_ylim(50000, 700000)
ax2.set_ylim(50000, 700000)

# 차트 제목 추가
ax1.set_title('서울 -> 경기 인구 이동', size=20)

# 축이름 추가
ax2.set_xlabel('기간', size=12)
ax2.set_ylabel('이동 인구수', size = 12)

# 축 눈금 라벨 지정 및 75도 회전
ax1.set_xticklabels(sr_one.index, rotation=75)
ax2.set_xticklabels(sr_one.index, rotation=75)

plt.show()  # 변경사항 저장하고 그래프 출력
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\960588392.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_one.index, rotation=75)
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\960588392.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_one.index, rotation=75)

# %% [markdown]
# ### 실습
# - 3개의 그래프를 그려보기
# - 2000년도부터 2010년까지 서울에서 충청남도, 경상북도, 강원도로 이동한 인구 데이터를
# - 각각의 그래프로 시각화하시오.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 서울에서 '충청남도','경상북도', '강원도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(2000, 2010)))
df_3 = df_seoul.loc[['충청남도','경상북도', '강원도'], col_years]

# 스타일 서식 지정
plt.style.use('ggplot') 

# 그래프 객체 생성 (figure에 1개의 서브 플롯을 생성)
fig = plt.figure(figsize=(20, 25))   
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 1, 2)
ax3 = fig.add_subplot(3, 1, 3)

# axe 객체에 plot 함수로 그래프 출력
ax1.plot(col_years, df_3.loc['충청남도',:], marker='o', markerfacecolor='green', 
        markersize=10, color='olive', linewidth=2, label='서울 -> 충남')
ax2.plot(col_years, df_3.loc['경상북도',:], marker='o', markerfacecolor='blue', 
        markersize=10, color='skyblue', linewidth=2, label='서울 -> 경북')
ax3.plot(col_years, df_3.loc['강원도',:], marker='o', markerfacecolor='red', 
        markersize=10, color='magenta', linewidth=2, label='서울 -> 강원')

# 범례 표시
ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')

# 차트 제목 추가
ax1.set_title('서울 -> 충남 인구 이동', size=20)
ax2.set_title('서울 -> 경북 인구 이동', size=20)
ax3.set_title('서울 -> 강원 인구 이동', size=20)

# 축이름 추가
ax1.set_xlabel('기간', size=12)
ax1.set_ylabel('이동 인구수', size = 20)
ax2.set_xlabel('기간', size=12)
ax2.set_ylabel('이동 인구수', size = 20)
ax3.set_xlabel('기간', size=12)
ax3.set_ylabel('이동 인구수', size = 20)

# 축 눈금 라벨 지정 및 90도 회전
ax1.set_xticklabels(col_years, rotation=90)
ax2.set_xticklabels(col_years, rotation=90)
ax3.set_xticklabels(col_years, rotation=90)

# 축 눈금 라벨 크기
ax1.tick_params(axis="x", labelsize=20)
ax1.tick_params(axis="y", labelsize=20)
ax2.tick_params(axis="x", labelsize=20)
ax2.tick_params(axis="y", labelsize=20)
ax3.tick_params(axis="x", labelsize=20)
ax3.tick_params(axis="y", labelsize=20)

plt.show()  # 변경사항 저장하고 그래프 출력
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\3199894066.py:50: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_years, rotation=90)
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\3199894066.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_years, rotation=90)
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\3199894066.py:52: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(col_years, rotation=90)

# %% [markdown]
# ### 하나의 그래프에 여러 값 표시하기
# - 하나의 피규어에 여러 그래프 그리기
# - 앞에서 그린 그래프를 하나로 표현(1970~2018)

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 서울에서 '충청남도','경상북도', '강원도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(1970, 2018)))
df_3 = df_seoul.loc[['충청남도','경상북도', '강원도'], col_years]

plt.style.use('ggplot') 

# 그래프 객체 생성 (figure에 1개의 서브 플롯을 생성)
fig = plt.figure(figsize=(20, 5))   
ax = fig.add_subplot(1, 1, 1)

# axe 객체에 plot 함수로 그래프 출력- 동일한 서브플롯에 plot을 계속 설정하는 것
ax.plot(col_years, df_3.loc['충청남도',:], marker='o', markerfacecolor='green', 
        markersize=10, color='olive', linewidth=2, label='서울 -> 충남')
ax.plot(col_years, df_3.loc['경상북도',:], marker='o', markerfacecolor='blue', 
        markersize=10, color='skyblue', linewidth=2, label='서울 -> 경북')
ax.plot(col_years, df_3.loc['강원도',:], marker='o', markerfacecolor='red', 
        markersize=10, color='magenta', linewidth=2, label='서울 -> 강원')

# 범례 표시
ax.legend(loc='best')

# 차트 제목 추가
ax.set_title('서울 -> 충남, 경북, 강원 인구 이동', size=20)

# 축이름 추가
ax.set_xlabel('기간', size=12)
ax.set_ylabel('이동 인구수', size = 12)

# 축 눈금 라벨 지정 및 90도 회전
ax.set_xticklabels(col_years, rotation=90)

# 축 눈금 라벨 크기
ax.tick_params(axis="x", labelsize=10)
ax.tick_params(axis="y", labelsize=10)

plt.show()  # 변경사항 저장하고 그래프 출력
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\1033592515.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(col_years, rotation=90)

# %% [markdown]
# ##### 해석
# - 서울에서 각각 지역으로 빠져나간 인구 이동을 비교
# - 지리적으로 가까운 충남 지역으로 이동한 인구가 다른 두 지역에 비해 많아 보임
# - 전반적으로 1970~1980년대에는 서울에서 지방으로 많이 이동했음
# - 1990년 이후로는 이동이 감소하는 패턴을 보임

# %% [markdown]
# ### 실습
# - 서울에서 충청남도, 경상북도, 강원도, 전라남도 4개의 지역으로 이동한 인구현황 그래프 그리기
# - 결과 화면 예시
# ![image-2.png](attachment:image-2.png)

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 서울에서 '충청남도','경상북도', '강원도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(1970, 2018)))
df_3 = df_seoul.loc[['충청남도','경상북도', '강원도', '전라남도'], col_years]

# 스타일 서식 지정
plt.style.use('ggplot') 

# 그래프 객체 생성 (figure에 1개의 서브 플롯을 생성)
fig = plt.figure(figsize=(20, 15))   
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# axe 객체에 plot 함수로 그래프 출력
ax1.plot(col_years, df_3.loc['충청남도',:], marker='o', markerfacecolor='green', 
        markersize=10, color='olive', linewidth=2, label='서울 -> 충남')
ax2.plot(col_years, df_3.loc['경상북도',:], marker='o', markerfacecolor='blue', 
        markersize=10, color='skyblue', linewidth=2, label='서울 -> 경북')
ax3.plot(col_years, df_3.loc['강원도',:], marker='o', markerfacecolor='red', 
        markersize=10, color='magenta', linewidth=2, label='서울 -> 강원')
ax4.plot(col_years, df_3.loc['전라남도',:], marker='o', markerfacecolor='gray', 
        markersize=10, color='gray', linewidth=2, label='서울 -> 전남')

# 범례 표시
ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')
ax4.legend(loc='best')


# 차트 제목 추가
ax1.set_title('서울 -> 충남 인구 이동', size=20)
ax2.set_title('서울 -> 경북 인구 이동', size=20)
ax3.set_title('서울 -> 강원 인구 이동', size=20)
ax4.set_title('서울 -> 전라 인구 이동', size=20)

# 축이름 추가
ax1.set_xlabel('기간', size=20)
ax1.set_ylabel('이동 인구수', size = 20)
ax2.set_xlabel('기간', size=20)
ax2.set_ylabel('이동 인구수', size = 20)
ax3.set_xlabel('기간', size=20)
ax3.set_ylabel('이동 인구수', size = 20)
ax4.set_xlabel('기간', size=20)
ax4.set_ylabel('이동 인구수', size = 20)

# 축 눈금 라벨 지정 및 90도 회전
ax1.set_xticklabels(col_years, rotation=90)
ax2.set_xticklabels(col_years, rotation=90)
ax3.set_xticklabels(col_years, rotation=90)
ax4.set_xticklabels(col_years, rotation=90)

# 축 눈금 라벨 크기
ax1.tick_params(axis="x", labelsize=10)
ax1.tick_params(axis="y", labelsize=10)
ax2.tick_params(axis="x", labelsize=10)
ax2.tick_params(axis="y", labelsize=10)
ax3.tick_params(axis="x", labelsize=10)
ax3.tick_params(axis="y", labelsize=10)
ax4.tick_params(axis="x", labelsize=10)
ax4.tick_params(axis="y", labelsize=10)

plt.show()  # 변경사항 저장하고 그래프 출력
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\2039394625.py:58: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_years, rotation=90)
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\2039394625.py:59: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_years, rotation=90)
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\2039394625.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(col_years, rotation=90)
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\2039394625.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(col_years, rotation=90)

# %%
# 라이브러리 불러오기
import matplotlib

# 컬러 정보를 담을 빈 딕셔너리 생성
colors={}

# 컬러 이름과 헥사코드 확인하여 딕셔서리에 입력
for name, hex in matplotlib.colors.cnames.items():
	colors[name] = hex

# 딕셔너리 출력    
colors
# Out:
# {'aliceblue': '#F0F8FF',
#  'antiquewhite': '#FAEBD7',
#  'aqua': '#00FFFF',
#  'aquamarine': '#7FFFD4',
#  'azure': '#F0FFFF',
#  'beige': '#F5F5DC',
#  'bisque': '#FFE4C4',
#  'black': '#000000',
#  'blanchedalmond': '#FFEBCD',
#  'blue': '#0000FF',
#  'blueviolet': '#8A2BE2',
#  'brown': '#A52A2A',
#  'burlywood': '#DEB887',
#  'cadetblue': '#5F9EA0',
#  'chartreuse': '#7FFF00',
#  'chocolate': '#D2691E',
#  'coral': '#FF7F50',
#  'cornflowerblue': '#6495ED',
#  'cornsilk': '#FFF8DC',
#  'crimson': '#DC143C',
#  'cyan': '#00FFFF',
#  'darkblue': '#00008B',
#  'darkcyan': '#008B8B',
#  'darkgoldenrod': '#B8860B',
#  'darkgray': '#A9A9A9',
#  'darkgreen': '#006400',
#  'darkgrey': '#A9A9A9',
#  'darkkhaki': '#BDB76B',
#  'darkmagenta': '#8B008B',
#  'darkolivegreen': '#556B2F',
#  'darkorange': '#FF8C00',
#  'darkorchid': '#9932CC',
#  'darkred': '#8B0000',
#  'darksalmon': '#E9967A',
#  'darkseagreen': '#8FBC8F',
#  'darkslateblue': '#483D8B',
#  'darkslategray': '#2F4F4F',
# ...

# %% [markdown]
# ## 면적 그래프
# - 면적 그래프는 각 열의 데이터를 선그래프로 구현
# - 선 그래프와 x축 사이의 공간에 색이 들어감
# - 누적 선 그래프(stacked line plot)라고 부르기도 함
# - 색의 투명도는 0~1사이의 값으로 지정 가능(디폴트: 0.5)
# - kind='area' 옵션을 추가하여 적용
# - 그래프를 누적할지 여부 설정(stacked=True)
# - 각 열의 선 그래프를 다른 열의 선 그래프 위로 쌓아 올리는 방식으로 표현
# - 각 열의 패턴과 열 전체의 합계를 파악할 수 있음

# %%
# 라이브러리 불러오기
import pandas as pd

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('시도별 전출입 인구수.xlsx', engine= 'openpyxl', header=0)

# 전출지별에서 누락값(NaN)을 앞 데이터로 채움 (엑셀 양식 병합 부분)
df = df.fillna(method='ffill')

# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 서울에서 '충청남도','경상북도', '강원도', '전라남도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(1970, 2018)))
df_4 = df_seoul.loc[['충청남도','경상북도', '강원도', '전라남도'], col_years]
df_4 = df_4.transpose()

df_4
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도
# 1970  15954  11868   9352  10513
# 1971  18943  16459  12885  16755
# 1972  23406  22073  13561  20157
# 1973  27139  27531  16481  22160
# 1974  25509  26902  15479  21314
# 1975  51205  46177  27837  46610
# 1976  41447  40376  25927  46251
# 1977  43993  41155  25415  43430
# 1978  48091  42940  26700  44624
# 1979  45388  43565  27599  47934
# 1980  54480  48839  32858  56251
# 1981  51369  30928  32116  57645
# 1982  48834  27440  31013  55408
# 1983  55344  29601  31308  57737
# 1984  50318  26842  30470  52779
# 1985  49520  26297  29911  52629
# 1986  47888  26221  28489  41082
# 1987  48678  27844  28699  42667
# 1988  49038  26235  26691  40695
# 1989  31707  22374  26394  36188
# 1990  29993  21490  26591  35589
# 1991  28211  19054  25208  29925
# 1992  26600  19342  25215  27258
# 1993  25958  17604  23244  25554
# 1994  22293  16067  21384  21737
# 1995  26501  17064  24987  24100
# 1996  27159  16899  25221  23790
# ...

# %%
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 스타일 서식 지정
plt.style.use('ggplot') 

# 데이터프레임의 인덱스를 정수형으로 변경 (x축 눈금 라벨 표시)
df_4.index = df_4.index.map(int)

# 면적 그래프 그리기 - stacked=False
df_4.plot(kind='area', stacked=False, alpha=0.2, figsize=(20, 10))

plt.title('서울 -> 타시도 인구 이동', size=30)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.legend(loc='best', fontsize=15)

plt.show()
# Out:
# C:\Users\itthi\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 스타일 서식 지정
plt.style.use('ggplot') 

# 데이터프레임의 인덱스를 정수형으로 변경 (x축 눈금 라벨 표시)
df_4.index = df_4.index.map(int)

# 면적 그래프 그리기 - stacked=True (default값)
df_4.plot(kind='area', alpha=0.2, figsize=(20, 10))

plt.title('서울 -> 타시도 인구 이동', size=30)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.legend(loc='best', fontsize=15)

plt.show()
# Out:
# C:\Users\itthi\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - plot()메서드로 생성한 그래프는 axe객체로 스타일 설정을 변경 할 수 있음

# %%
# 면적 그래프 axe 객체 생성
ax = df_4.plot(kind='area', stacked=True, alpha=0.2, figsize=(20, 10))
print(type(ax))

# axe 객체 설정 변경
ax.set_title('서울 -> 타시도 인구 이동', size=30, color='brown', weight='bold')
ax.set_ylabel('이동 인구 수', size=20, color='blue')
ax.set_xlabel('기간', size=20, color='blue')
ax.legend(loc='best', fontsize=15)

plt.show()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# C:\Users\itthi\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 막대 그래프
# - 데이터 값의 크기에 비례하여 높이를 갖는 직사각형 막대로 표현
# - 막대 높이의 상대적 길이 차이를 통해 값의 크고 작음을 설명
#
# ### 세로형/가로형
#
# - 세로형
# 	- 선 그래프와 정보제공 측면에서는 유의미한 차이가 없음
# 	- 시간적으로 차이가 나는 두 점에서 데이터 값의 차이를 잘 설명함(시계열 데이터)
# 	- plot()메서드에 kind='bar'옵션으로 설정
#
# - 가로형
# 	- 각 변수 사이 값의 크기 차이를 설명하는 데에 적합
# 	- plot()메서드에 kind='barh'옵션으로 설정

# %% [markdown]
# ### 세로형 예제
# - 2010~2018데이터 추출

# %%
# 라이브러리 불러오기
import pandas as pd

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('시도별 전출입 인구수.xlsx', engine= 'openpyxl', header=0)

# 전출지별에서 누락값(NaN)을 앞 데이터로 채움 (엑셀 양식 병합 부분)
df = df.fillna(method='ffill')

# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 서울에서 '충청남도','경상북도', '강원도', '전라남도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(2010, 2018)))     
df_4 = df_seoul.loc[['충청남도','경상북도', '강원도', '전라남도'], col_years]
df_4 = df_4.transpose()
df_4
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도
# 2010  24522  16042  22736  16429
# 2011  24723  15818  23624  15974
# 2012  22269  15191  22332  14765
# 2013  21486  14420  20601  14187
# 2014  21473  14456  21173  14591
# 2015  22299  15113  22659  14598
# 2016  21741  14236  21590  13065
# 2017  21020  12464  21016  12426

# %%
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 스타일 서식 지정
plt.style.use('ggplot') 

# 데이터프레임의 인덱스를 정수형으로 변경 (x축 눈금 라벨 표시)
df_4.index = df_4.index.map(int)

# 막대 그래프 그리기
df_4.plot(kind='bar', figsize=(20, 10), width=0.7, color=['orange', 'green', 'skyblue', 'blue'])

plt.title('서울 -> 타시도 인구 이동', size=30)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.ylim(5000, 30000)
plt.legend(loc='best', fontsize=15)

plt.show()

# %% [markdown]
# #### 가로형 예제

# %%
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 스타일 서식 지정
plt.style.use('ggplot') 

# 수평 막대 그래프 그리기
df_4.plot(kind='barh', color=['orange', 'green', 'skyblue', 'blue'], width=0.5, figsize=(10, 5))

plt.title('서울 -> 타시도 인구 이동')
plt.ylabel('전입지')
plt.xlabel('이동 인구 수')

plt.show()

# %% [markdown]
# ##### 결과
# - 세로형을 옆으로 돌린 형태로 보여짐

# %% [markdown]
# #### 서울에서 각 시도별로 이동한 인구의 합계를 구하여 시도별로 비교하는 그래프 그리기

# %%
# 2010-2017년 이동 인구 수를 합계하여 새로운 열로 추가
df_4['합계'] = df_4.sum(axis=1)
df_4
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도        합계
# 2010  24522  16042  22736  16429  159458.0
# 2011  24723  15818  23624  15974  160278.0
# 2012  22269  15191  22332  14765  149114.0
# 2013  21486  14420  20601  14187  141388.0
# 2014  21473  14456  21173  14591  143386.0
# 2015  22299  15113  22659  14598  149338.0
# 2016  21741  14236  21590  13065  141264.0
# 2017  21020  12464  21016  12426  133852.0

# %%
# 가장 큰 값부터 정렬
df_total = df_4[['합계']].sort_values(by='합계', ascending=True)
df_total
# Out:
# 전입지         합계
# 2017  133852.0
# 2016  141264.0
# 2013  141388.0
# 2014  143386.0
# 2012  149114.0
# 2015  149338.0
# 2010  159458.0
# 2011  160278.0

# %%
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 스타일 서식 지정
plt.style.use('ggplot') 

# 수평 막대 그래프 그리기
df_total.plot(kind='barh', color='cornflowerblue', width=0.5, figsize=(10, 5))

plt.title('서울 -> 타시도 인구 이동')
plt.ylabel('전입지')
plt.xlabel('이동 인구 수')

plt.show()

# %% [markdown]
# #### 보조축 활용하기(2축 그래프)
# - 2개의 y축을 이용하는 방법
# - 남북한 발전량 데이터셋 사용
# - 기존 축에는 막대그래프 값(연도별 북한의 발전량)을 표시
# - 보조 축에는 선 그래프의 값(북한 발전량의 전년 대비 증감률)을 표시

# %%
#전체코드
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.style.use('ggplot')   # 스타일 서식 지정
plt.rcParams['axes.unicode_minus']=False   # 마이너스 부호 출력 설정

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('./남북한발전전력량.xlsx', engine= 'openpyxl', convert_float=True)
df = df.loc[5:9]

df.drop('전력량 (억㎾h)', axis='columns', inplace=True)
df.set_index('발전 전력별', inplace=True)
df = df.T
# 증감율(변동률) 계산
df = df.rename(columns={'합계':'총발전량'})
df['총발전량 - 1년'] = df['총발전량'].shift(1)
df['증감율'] = ((df['총발전량'] / df['총발전량 - 1년'])) * 100 

# 2축 그래프 그리기
ax1 = df[['수력','화력']].plot(kind='bar', figsize=(20, 10), width=0.7, stacked=True)  
ax2 = ax1.twinx()
ax2.plot(df.index, df.증감율, ls='--', marker='o', markersize=20, 
         color='green', label='전년대비 증감율(%)')  

ax1.set_ylim(0, 500)
ax2.set_ylim(-50, 50)

ax1.set_xlabel('연도', size=20)
ax1.set_ylabel('발전량(억 KWh)')
ax2.set_ylabel('전년 대비 증감율(%)')

plt.title('북한 전력 발전량 (1990 ~ 2016)', size=30)
ax1.legend(loc='upper left')

plt.show()
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\3162376149.py:16: FutureWarning: convert_float is deprecated and will be removed in a future version.
#   df = pd.read_excel('./남북한발전전력량.xlsx', engine= 'openpyxl', convert_float=True)

# %% [markdown]
# #### 단계별로 분석하여 이해

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.style.use('ggplot')   # 스타일 서식 지정
plt.rcParams['axes.unicode_minus']=False   # 마이너스 부호 출력 설정

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('./남북한발전전력량.xlsx', engine= 'openpyxl', convert_float=True)
df
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\1644702847.py:15: FutureWarning: convert_float is deprecated and will be removed in a future version.
#   df = pd.read_excel('./남북한발전전력량.xlsx', engine= 'openpyxl', convert_float=True)
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# ...

# %% [markdown]
# #### 북한 데이터만 가져오기

# %%
df = df.loc[5:9]
df
# Out:
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
# 8       NaN    원자력    -    -    -    -    -    -    -    -  ...    -    -
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -    -
#
# [4 rows x 29 columns]

# %% [markdown]
# #### 첫 번째 열 삭제

# %%
df.drop('전력량 (억㎾h)', axis='columns', inplace=True)
df
# Out:
# C:\Users\itthi\AppData\Local\Temp\ipykernel_5424\1437538302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('전력량 (억㎾h)', axis='columns', inplace=True)
#   발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997 1998  ... 2007 2008 2009  \
# 5     합계  277  263  247  221  231  230  213  193  170  ...  236  255  235
# 6     수력  156  150  142  133  138  142  125  107  102  ...  133  141  125
# 7     화력  121  113  105   88   93   88   88   86   68  ...  103  114  110
# 8    원자력    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#   2010 2011 2012 2013 2014 2015 2016
# 5  237  211  215  221  216  190  239
# 6  134  132  135  139  130  100  128
# 7  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -
#
# [4 rows x 28 columns]

# %% [markdown]
# #### 발전 전력별 열을 인덱스로 설정

# %%
df.set_index('발전 전력별', inplace=True)
df
# Out:
#        1990 1991 1992 1993 1994 1995 1996 1997 1998 1999  ... 2007 2008 2009  \
# 발전 전력별                                                    ...
# 합계      277  263  247  221  231  230  213  193  170  186  ...  236  255  235
# 수력      156  150  142  133  138  142  125  107  102  103  ...  133  141  125
# 화력      121  113  105   88   93   88   88   86   68   83  ...  103  114  110
# 원자력       -    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#        2010 2011 2012 2013 2014 2015 2016
# 발전 전력별
# 합계      237  211  215  221  216  190  239
# 수력      134  132  135  139  130  100  128
# 화력      103   79   80   82   86   90  111
# 원자력       -    -    -    -    -    -    -
#
# [4 rows x 27 columns]

# %% [markdown]
# #### 행렬 전치

# %%
df = df.T 
df
# Out:
# 발전 전력별   합계   수력   화력 원자력
# 1990    277  156  121   -
# 1991    263  150  113   -
# 1992    247  142  105   -
# 1993    221  133   88   -
# 1994    231  138   93   -
# 1995    230  142   88   -
# 1996    213  125   88   -
# 1997    193  107   86   -
# 1998    170  102   68   -
# 1999    186  103   83   -
# 2000    194  102   92   -
# 2001    202  106   96   -
# 2002    190  106   84   -
# 2003    196  117   79   -
# 2004    206  125   81   -
# 2005    215  131   84   -
# 2006    225  126   99   -
# 2007    236  133  103   -
# 2008    255  141  114   -
# 2009    235  125  110   -
# 2010    237  134  103   -
# 2011    211  132   79   -
# 2012    215  135   80   -
# 2013    221  139   82   -
# 2014    216  130   86   -
# 2015    190  100   90   -
# 2016    239  128  111   -

# %% [markdown]
# #### 합계 열의 이름을 총발전량으로 변경

# %%
# 증감율(변동률) 계산
df = df.rename(columns={'합계':'총발전량'})
df
# Out:
# 발전 전력별 총발전량   수력   화력 원자력
# 1990    277  156  121   -
# 1991    263  150  113   -
# 1992    247  142  105   -
# 1993    221  133   88   -
# 1994    231  138   93   -
# 1995    230  142   88   -
# 1996    213  125   88   -
# 1997    193  107   86   -
# 1998    170  102   68   -
# 1999    186  103   83   -
# 2000    194  102   92   -
# 2001    202  106   96   -
# 2002    190  106   84   -
# 2003    196  117   79   -
# 2004    206  125   81   -
# 2005    215  131   84   -
# 2006    225  126   99   -
# 2007    236  133  103   -
# 2008    255  141  114   -
# 2009    235  125  110   -
# 2010    237  134  103   -
# 2011    211  132   79   -
# 2012    215  135   80   -
# 2013    221  139   82   -
# 2014    216  130   86   -
# 2015    190  100   90   -
# 2016    239  128  111   -

# %% [markdown]
# #### '총발전량 - 1년'열을 생성하여 '총발전량'을 shift()메서드로 뒤로 하나씩 이동시켜 저장

# %%
df['총발전량 - 1년'] = df['총발전량'].shift(1)
df
# Out:
# 발전 전력별 총발전량   수력   화력 원자력 총발전량 - 1년
# 1990    277  156  121   -       NaN
# 1991    263  150  113   -       277
# 1992    247  142  105   -       263
# 1993    221  133   88   -       247
# 1994    231  138   93   -       221
# 1995    230  142   88   -       231
# 1996    213  125   88   -       230
# 1997    193  107   86   -       213
# 1998    170  102   68   -       193
# 1999    186  103   83   -       170
# 2000    194  102   92   -       186
# 2001    202  106   96   -       194
# 2002    190  106   84   -       202
# 2003    196  117   79   -       190
# 2004    206  125   81   -       196
# 2005    215  131   84   -       206
# 2006    225  126   99   -       215
# 2007    236  133  103   -       225
# 2008    255  141  114   -       236
# 2009    235  125  110   -       255
# 2010    237  134  103   -       235
# 2011    211  132   79   -       237
# 2012    215  135   80   -       211
# 2013    221  139   82   -       215
# 2014    216  130   86   -       221
# ...

# %% [markdown]
# #### 전년도 대비 변동율을 계산한 결과를 '증감율'열에 저장

# %%
df['증감율'] = ((df['총발전량'] / df['총발전량 - 1년'])) * 100      
df
# Out:
# 발전 전력별 총발전량   수력   화력 원자력 총발전량 - 1년         증감율
# 1990    277  156  121   -       NaN         NaN
# 1991    263  150  113   -       277   94.945848
# 1992    247  142  105   -       263    93.91635
# 1993    221  133   88   -       247   89.473684
# 1994    231  138   93   -       221  104.524887
# 1995    230  142   88   -       231     99.5671
# 1996    213  125   88   -       230   92.608696
# 1997    193  107   86   -       213   90.610329
# 1998    170  102   68   -       193   88.082902
# 1999    186  103   83   -       170  109.411765
# 2000    194  102   92   -       186  104.301075
# 2001    202  106   96   -       194  104.123711
# 2002    190  106   84   -       202   94.059406
# 2003    196  117   79   -       190  103.157895
# 2004    206  125   81   -       196  105.102041
# 2005    215  131   84   -       206  104.368932
# 2006    225  126   99   -       215  104.651163
# 2007    236  133  103   -       225  104.888889
# 2008    255  141  114   -       236  108.050847
# ...

# %% [markdown]
# #### 그래프 그리기

# %%
# 2축 그래프 그리기
ax1 = df[['수력','화력']].plot(kind='bar', figsize=(20, 10), width=0.7, stacked=True)  
ax2 = ax1.twinx()
ax2.plot(df.index, df.증감율, ls='--', marker='o', markersize=20, 
         color='green', label='전년대비 증감율(%)')  

ax1.set_ylim(0, 500)
ax2.set_ylim(-50, 50)

ax1.set_xlabel('연도', size=20)
ax1.set_ylabel('발전량(억 KWh)')
ax2.set_ylabel('전년 대비 증감율(%)')

plt.title('북한 전력 발전량 (1990 ~ 2016)', size=30)
ax1.legend(loc='upper left')

plt.show()

# %% [markdown]
# ##### 해석
# - 2015년 수력 발전량이 급감한 부분이 보인다.
# - 기사를 검색하여 무엇 때문이었는지 조사한다.
#     - https://www.e-ia.co.kr/sonosa/newsletter/201702/column.html
#     ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 히스토그램
# - 히스토그램은 변수가 하나인 단변수 데이터의 빈도수를 그래프로 표현
# - x축을 같은 크기의 여러 구간으로 나눠 각 구간에 속하는 데이터 값의 개수(빈도)를 y축에 표시.
# - 구간을 나누는 간격의 크기에 따라 빈도가 달라지고 히스토그램 모양이 변한다.
# - plot() 메서드에 kind='hist' 옵션으로 설정

# %% [markdown]
# ### UCI의 자동차 연비 데이터 셋을 이용하여 실습

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('classic')   # 스타일 서식 지정

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 연비(mpg) 열에 대한 히스토그램 그리기
df['mpg'].plot(kind='hist', bins=10, color='coral', figsize=(10, 5))

# 그래프 꾸미기
plt.title('Histogram')
plt.xlabel('mpg')
plt.show()

# %% [markdown]
# ##### 해석
# - 자동차 연비 값은 대부분 왼쪽으로 편향되어 있어 연비가 낮은 구간이 집중된 형태로 보임

# %% [markdown]
# ## 산점도(scatter)
# - 두 연속 변수의 관계를 보여주는 것만 보면 선그래프와 비슷
# - 선 그래프를 그릴 때 plot()메서드에 'o'옵션을 사용한 경우 사실상 산점도
#
# - 서로 다른 두 변수 사이의 관계를 나타냄
# - 각 변수는 연속되는 값을 가짐
# - 일반적으로 자료형은 정수(int64) 또는 실수(float64)
# - 2개의 연속 변수를 각각 x축과 y축에 하나씩 놓고
# - 데이터 값이 위치하는 (x,y)좌표를 찾아 점으로 표시
# - plot()메서드에 kind='scatter' 옵션으로 적용
#     - 점의 색상 c
#     - 크기 s

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')   # 스타일 서식 지정

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 연비(mpg)와 차중(weight) 열에 대한 산점도 그리기
df.plot(kind='scatter', x='weight', y='mpg',  c='coral', s=10, figsize=(10, 5))
plt.title('Scatter Plot - mpg vs. weight')
plt.show()

# %% [markdown]
# ##### 해석
# - 자동차 무게와 연비의 관계를 표현
# - 무게가 무거우면 연비가 좋지 않은 경향을 보임(선형)

# %% [markdown]
# ### 또 다른 변수를 추가하여 점의 크기 또는 색상으로 표현 가능
# - 실린더 개수 추가
# - 그냥 추가하는 경우 점의 크기가 자세히 보여지지 않으므로 값을 비율을 유지하여 키움

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')   # 스타일 서식 지정

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# cylinders 개수의 상대적 비율을 계산하여 시리즈 생성
cylinders_size = df.cylinders / df.cylinders.max() * 300

# 3개의 변수로 산점도 그리기 
df.plot(kind='scatter', x='weight', y='mpg', c='coral', figsize=(10, 5),
        s=cylinders_size, alpha=0.3)
plt.title('Scatter Plot: mpg-weight-cylinders')
plt.show()

# %% [markdown]
# ## 그래프를 그림으로 저장
# - 보고서 작성에 활용할 수 있다.

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')   # 스타일 서식 지정

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# cylinders 개수의 상대적 비율을 계산하여 시리즈 생성
cylinders_size = df.cylinders / df.cylinders.max() * 300

# 3개의 변수로 산점도 그리기 
df.plot(kind='scatter', x='weight', y='mpg', marker='+', figsize=(10, 5),
        cmap='viridis', c=cylinders_size, s=50, alpha=0.3)
plt.title('Scatter Plot: mpg-weight-cylinders')

plt.savefig("./scatter.png")    
plt.savefig("./scatter_transparent.png", transparent=True)            # savefig : 보여진 그래프를 파일형식으로 저장

plt.show()

# %% [markdown]
# #### 저장된 파일 확인
# ![image-2.png](attachment:image-2.png)
#
# - 그래프의 색상은 다음을 참조: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ## 파이차트
# - 원을 조각으로 나누어 표현
# - 조각의 크기는 해당 변수에 속하는 데이터 값의 크기에 비례
# - plot()메서드에 kind='pie' 옵션으로 적용
#
# origin
# 1 = USA
# 2 = EU
# 3 = JPN

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

plt.style.use('default')   # 스타일 서식 지정

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 데이터 개수 카운트를 위해 값 1을 가진 열을 추가
df['count'] = 1
df_origin = df.groupby('origin').sum()   # origin 열을 기준으로 그룹화, 합계 연산
df_origin.head()                  # 그룹 연산 결과 출력
# Out:
#            mpg  cylinders  displacement    weight  acceleration  model year  \
# origin
# 1       5000.8       1556       61229.5  837121.0        3743.4       18827
# 2       1952.4        291        7640.0  169631.0        1175.1        5307
# 3       2405.6        324        8114.0  175477.0        1277.6        6118
#
#         count
# origin
# 1         249
# 2          70
# 3          79

# %%
# 제조국가(origin) 값을 실제 지역명으로 변경
df_origin.index = ['USA', 'EU', 'JAPAN']

# 제조국가(origin) 열에 대한 파이 차트 그리기 – count 열 데이터 사용
df_origin['count'].plot(kind='pie', 
                     figsize=(7, 5),
                     autopct='%1.1f%%',   # 퍼센트 % 표시
                     startangle=10,       # 파이 조각을 나누는 시작점(각도 표시)
                     colors=['chocolate', 'bisque', 'cadetblue']    # 색상 리스트
                     )

plt.title('Model Origin', size=20)
plt.axis('equal')    # 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.legend(labels=df_origin.index, loc='upper right')   # 범례 표시
plt.show()

# %% [markdown]
# ## 박스플롯
# - 범주형 데이터의 분포를 파악하는 용도로 적합
# - 5개의 통계지표 를 제공
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 제조 국가별 연비 분포를 보여주는 박스플롯 예제

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# plt.style.use('seaborn-poster')            # 스타일 서식 지정
# plt.rcParams['axes.unicode_minus']=False   # 마이너스 부호 출력 설정

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 그래프 객체 생성 (figure에 2개의 서브 플롯을 생성)
fig = plt.figure(figsize=(15, 5))   
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

# axe 객체에 boxplot 메서드로 그래프 출력
ax1.boxplot(x=[df[df['origin']==1]['mpg'],
               df[df['origin']==2]['mpg'],
               df[df['origin']==3]['mpg']], 
         labels=['USA', 'EU', 'JAPAN'])

ax2.boxplot(x=[df[df['origin']==1]['mpg'],
               df[df['origin']==2]['mpg'],
               df[df['origin']==3]['mpg']], 
         labels=['USA', 'EU', 'JAPAN'],
         vert=False)

ax1.set_title('제조국가별 연비 분포(수직 박스 플롯)')
ax2.set_title('제조국가별 연비 분포(수평 박스 플롯)')

plt.show()

# %% [markdown]
# ##### 해석
# - USA에서 제조한 차의 연비는 15 ~ 24정도 사이에 분포함
# - 이상 값으로 보이는 최대 값 범위를 벗어난 연비 데이터가 있음
# - EU, JAPAN 모두 최대값을 넘기는 이상치가 보임

# %% [markdown]
# ### 파이썬 그래프 갤러리
# - 다음 사이트를 참조하여 시각화에 활용:
# https://www.python-graph-gallery.com/
# ![image-2.png](attachment:image-2.png)
